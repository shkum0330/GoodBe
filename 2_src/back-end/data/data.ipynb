# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import deque

# %%
df = pd.read_json('job_data.json')
df
# Out:
#                     id        company_id  \
# 0     K151422307280043        미성엔지니어링(주)
# 1     K120422307280015         (주)솔루텍시스템
# 2     K151322307280003           (주)하이앤텍
# 3     K151632307270033           수퍼빈주식회사
# 4     K120612307260032            웨일시큐리티
# ...                ...               ...
# 1705  K120142305300034           (주)텐핑거스
# 1706  K120032305300037         (주)더크림유니언
# 1707  K120032305300036         (주)더크림유니언
# 1708  K120612305300040  주식회사 피플 글로우(PLG)
# 1709  K160042305300034               아이카
#
#                                       company_data              company_url  \
# 0         채규섭,14 명,200 백만원,1990 백만원,건축설계 및 관련 서비스업
# 1        이인명,26 명,500 백만원,11300 백만원,소프트웨어 개발 및 공급업        www.solutek.co.kr
# 2            임세용,15 명,250 백만원,7000 백만원,유선 통신장비 제조업            www.hi-nt.com
# 3     김정빈,146 명,0 백만원,0 백만원,그 외 기타 분류 안된 사업지원 서비스업       www.superbin.co.kr
# 4       이성민,8 명,150 백만원,800 백만원,시스템 소프트웨어 개발 및 공급업       www.whalesec.co.kr
# ...

# %%
df.to_json("jj2.json", orient="index")
