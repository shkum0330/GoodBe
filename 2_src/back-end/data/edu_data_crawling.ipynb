# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import deque

# %%
# 경로
# job_api_path = r"edu_api_key.txt"
edu_api_path = r"C:\SH\공통프로젝트\edu_api_key.txt"
# api key
with open(edu_api_path, "r") as f:
    api_key = f.read()

# %%
print(api_key)
# Out:
# y2bfFRDvOhLt10LVoCszji0iFNdtB2lZ

# %%
# 데이터 집어넣을 곳
edu_df = pd.DataFrame(columns=['trprId', 'TITLE', 'TITLE_LINK', 'SUB_TITLE', 'SUB_TITLE_LINK', 'TEL_NO', 'ADDRESS', 'content'])
# trprId : 훈련과정 ID
# TITLE : 훈련과정 이름
# TITLE_LINK : 훈련과정 url
# SUB_TITLE : 훈련기관 이름
# SUB_TITLE_LINK : 훈련기관 url
# TEL_NO : 훈련기관 전화번호
# ADDRESS : 훈련기관 주소
# content : 훈련 정보

# %%
api_url = f"https://www.hrd.go.kr/hrdp/api/apipo/APIPO0101T.do?outType=1&sort=ASC&srchTraArea1=00&srchTraStDt=20230731&pageSize=100&srchTraEndDt=20231031&sortCol=TRNG_BGDE&pageNum=1&authKey={api_key}&crseTracseSe=C0054I,C0104,C0105&returnType=XML&srchTraPattern=N1&srchPart=-99&apiRequstPageUrlAdres=/jsp/HRDP/HRDPO00/HRDPOA60/HRDPOA60_1.jsp&apiRequstIp=211.192.252.176"
req = requests.get(api_url).text
soup = BeautifulSoup(req, 'xml')
# cnt = 0
# for i in soup.find_all("scn_list"):
#     cnt += 1
#     print(i)

print(req)
print(soup)
# Out:
# <?xml version="1.0" encoding="EUC-KR"?>
# <HRDNet><pageNum>1</pageNum><pageSize>100</pageSize><scn_cnt>1053</scn_cnt><srchList><scn_list><address>경기 성남시 중원구</address><contents/><courseMan>8529300</courseMan><eiEmplCnt3/><eiEmplCnt3Gt10/><eiEmplRate3/><eiEmplRate6/><grade/><instCd>201400974</instCd><ncsCd>20010202</ncsCd><realMan>8529300</realMan><regCourseMan>0</regCourseMan><subTitle>에듀윌 국비교육원 성남센터</subTitle><subTitleLink>https://www.hrd.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000412872&amp;tracseTme=2&amp;trainstCstmrId=500020011165&amp;crseTracseSe=C0061</subTitleLink><telNo>031-604-0600</telNo><title>[K-디지털] C#기반 스마트팩토리 솔루션 개발자 양성과정_MES 개발언어 활용</title><titleIcon/><titleLink>https://www.hrd.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000412872&amp;tracseTme=2&amp;trainstCstmrId=500020011165&amp;crseTracseSe=C0061</titleLink><traEndDate>2024-01-12</traEndDate><traStartDate>2023-07-31</traStartDate><trainTarget>K-디지털 트레이닝</trainTarget><trainTargetCd>C0104</trainTargetCd><trainstCstId>500020011165</trainstCstId><trngAreaCd>41133</trngAreaCd><trprDegr>2</trprDegr><trprId>AIG20230000412872</trprId><yardMan>25</yardMan></scn_list><scn_list><address>서울 마포구</address><contents/><courseMan>10291320</courseMan><eiEmplCnt3/><eiEmplCnt3Gt10/><eiEmplRate3/><eiEmplRate6/><grade/><instCd>200601212</instCd><ncsCd>20010105</ncsCd><realMan>10291320</realMan><regCourseMan>0</regCourseMan><subTitle>서울IT아카데미 홍대</subTitle><subTitleLink>https://www.hrd.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20230000412797&amp;tracseTme=2&amp;trainstCstmrId=500020028504&amp;crseTracseSe=C0061</subTitleLink><telNo>02-2278-5700</telNo><title>엘라스틱서치를 활용한 빅데이터-자바(Java) 융합개발 인재양성</title><titleIcon/><titleLink>https://www.hrd.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20230000412797&amp;tracseTme=2&amp;trainstCstmrId=500020028504&amp;crseTracseSe=C0061</titleLink><traEndDate>2024-02-14</traEndDate><traStartDate>2023-07-31</traStartDate><trainTarget>K-디지털 트레이닝</trainTarget><trainTargetCd>C0104</trainTargetCd><trainstCstId>500020028504</trainstCstId><trngAreaCd>11440</trngAreaCd><trprDegr>2</trprDegr><trprId>AIG20230000412797</trprId><yardMan>23</yardMan></scn_list><scn_list><address>서울 강남구</address><contents/><courseMan>347000</courseMan><eiEmplCnt3>7</eiEmplCnt3><eiEmplCnt3Gt10/><eiEmplRate3>33.333</eiEmplRate3><eiEmplRate6>38.095</eiEmplRate6><grade/><instCd>202003272</instCd><ncsCd>20010304</ncsCd><realMan>347000</realMan><regCourseMan>2</regCourseMan><subTitle>(주)엘리스그룹</subTitle><subTitleLink>https://www.hrd.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20220000409541&amp;tracseTme=20&amp;trainstCstmrId=500038398274&amp;crseTracseSe=C0105</subTitleLink><telNo>070-4633-4851</telNo><title>비전공자를 위한 R 데이터 분석 기초 프로젝트</title><titleIcon/><titleLink>https://www.hrd.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20220000409541&amp;tracseTme=20&amp;trainstCstmrId=500038398274&amp;crseTracseSe=C0105</titleLink><traEndDate>2023-09-08</traEndDate><traStartDate>2023-07-31</traStartDate><trainTarget>K-디지털 기초역량훈련</trainTarget><trainTargetCd>C0105</trainTargetCd><trainstCstId>500038398274</trainstCstId><trngAreaCd>11680</trngAreaCd><trprDegr>20</trprDegr><trprId>AIG20220000409541</trprId><yardMan>200</yardMan></scn_list><scn_list><address>서울 강남구</address><contents/><courseMan>99000</courseMan><eiEmplCnt3>6</eiEmplCnt3><eiEmplCnt3Gt10/><eiEmplRate3>28.571</eiEmplRate3><eiEmplRate6>38.095</eiEmplRate6><grade/><instCd>202003272</instCd><ncsCd>20010202</ncsCd><realMan>99000</realMan><regCourseMan>1</regCourseMan><subTitle>(주)엘리스그룹</subTitle><subTitleLink>https://www.hrd.go.kr/hrdp/co/pcoco/PCOCO0100P.do?tracseId=AIG20210000328621&amp;tracseTme=35&amp;trainstCstmrId=500038398274&amp;crseTracseSe=C0105</subTitleLink><telNo>070-4633-4851</telNo><title>데이터 분석의 첫걸음! 파이썬 객체지향 프로그래밍</title><titleIcon/><titleLink>https://www.hrd.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20210000328621&amp;tracseTme=35&amp;trainstCstmrId=500038398274&amp;crseTracseSe=C0105</titleLink><traEndDate>2023-09-08</traEndDate><traSt ...
#
# <?xml version="1.0" encoding="utf-8"?>
# <HRDNet><pageNum>1</pageNum><pageSize>100</pageSize><scn_cnt>1053</scn_cnt><srchList><scn_list><address/></scn_list></srchList></HRDNet>

# %%
for page in range(1,1000):
    api_url = "https://www.hrd.go.kr/jsp/HRDP/HRDPO00/HRDPOA60/HRDPOA60_1.jsp?returnType=XML&authKey={api_key}&pageNum=1&pageSize=100&srchTraStDt=20230731&srchTraEndDt=20230731&outType=1&sort=ASC&sortCol=TRNG_BGDE&crseTracseSe=C0054I,C0104,C0105&srchTraArea1=00"
    cnt = 0
    req = requests.get(api_url)
    soup = BeautifulSoup(req.text, 'xml')
    for i in soup.find_all("wanted"):
        cnt += 1
        wanted_auth_no = i.find("wantedAuthNo").get_text()
        auth_no_list.append(wanted_auth_no)
    if cnt == 0:
        break
